# %% [markdown]
# #LETS GROW MORE-AUGUST
#
# ###DATA SCIENCE -INTERNSHIP
# ###AUTHOR: NITHEESH KUMAR GORLA
#
# ###TASK: Image to Pencil Sketch with Python:

# %% [markdown]
# ###importing the required lilibraries

# %%
# importing libraries
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the Image

# %%
image=cv2.imread("/content/Leopard_cat_Cats_Foliage_Grass_Lying_down_Glance_606151_600x400.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FE49351C8D0>

# %% [markdown]
# ### Converting Image into Gray scale image

# %%
gray_scale_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) # converting image from RGB to GRAY scale image
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7FE49340A110>

# %% [markdown]
# ###Inverting the gray scale image

# %%
inverted_image = cv2.bitwise_not(gray_scale_image)  # using bitwise_not func to invert the image

cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7FE4934289D0>

# %% [markdown]
# ###Image smoothing

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
#We have used the gaussian blur technique with 21 x 21 pixel and the default sigma values filter on the image to smoothen our image.
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7FE4933DF050>

# %% [markdown]
# ###Getting the final pencil sketch

# %%
def pencil_sketch(x, y):
#dividing the greyscale value of the image by the inverse of blurred image value which highlights the boldest edges of an image
    return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch=pencil_sketch(gray_scale_image,img_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7FE4934D6390>

# %%
cv2_imshow(image)

cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FE4934D6C90>
# <PIL.Image.Image image mode=L size=600x400 at 0x7FE4934D6350>
